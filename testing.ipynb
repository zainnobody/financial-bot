# %%
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Retrieve API key from environment variable
API_KEY = os.getenv('FRED_API_KEY')

def fetch_gdp():
    url = "https://api.worldbank.org/v2/country/USA/indicator/NY.GDP.MKTP.CD?format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error fetching GDP data:", response.status_code)
        print(response.text)
        return None

def fetch_inflation_rate():
    url = f"https://api.stlouisfed.org/fred/series/observations?series_id=CPIAUCSL&api_key={API_KEY}&file_type=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error fetching inflation rate data:", response.status_code)
        print(response.text)
        return None

def fetch_unemployment_rate():
    url = f"https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key={API_KEY}&file_type=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error fetching unemployment rate data:", response.status_code)
        print(response.text)
        return None

# Fetching the data
gdp_data = fetch_gdp()
inflation_rate_data = fetch_inflation_rate()
unemployment_rate_data = fetch_unemployment_rate()

# Printing the fetched data
print("GDP Data:", gdp_data)
print("Inflation Rate Data:", inflation_rate_data)
print("Unemployment Rate Data:", unemployment_rate_data)
# Out:
# GDP Data: [{'page': 1, 'pages': 2, 'per_page': 50, 'total': 64, 'sourceid': '2', 'lastupdated': '2024-05-30'}, [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2023', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2022', 'value': 25439700000000, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2021', 'value': 23315080560000, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'US', 'value': 'United States'}, 'countryiso3code': 'USA', 'date': '2020', 'value': 21060473613000, 'unit': '
# ...

# %%
import pandas as pd



gdp_df = df = pd.DataFrame({
    "Country": [item["country"]["value"] for item in gdp_data[1]],
    "Country Code": [item["countryiso3code"] for item in gdp_data[1]],
    "Year": [item["date"] for item in gdp_data[1]],
    "GDP (current US$)": [item["value"] for item in gdp_data[1]]
})

gdp_df
# Out:
#           Country Country Code  Year  GDP (current US$)
# 0   United States          USA  2023                NaN
# 1   United States          USA  2022       2.543970e+13
# 2   United States          USA  2021       2.331508e+13
# 3   United States          USA  2020       2.106047e+13
# 4   United States          USA  2019       2.138098e+13
# 5   United States          USA  2018       2.053306e+13
# 6   United States          USA  2017       1.947734e+13
# 7   United States          USA  2016       1.869511e+13
# 8   United States          USA  2015       1.820602e+13
# 9   United States          USA  2014       1.755068e+13
# 10  United States          USA  2013       1.684319e+13
# 11  United States          USA  2012       1.625397e+13
# 12  United States          USA  2011       1.559973e+13
# 13  United States          USA  2010       1.504896e+13
# 14  United States          USA  2009       1.447806e+13
# 15  United States          USA  2008       1.476986e+13
# ...

# %%
inflation_rate_df = pd.DataFrame(inflation_rate_data['observations'])

unemployment_rate_df = pd.DataFrame(unemployment_rate_data['observations'])

# Display the DataFrames
print("GDP DataFrame:")
print(gdp_df.head())

print("\nInflation Rate DataFrame:")
print(inflation_rate_df.head())

print("\nUnemployment Rate DataFrame:")
print(unemployment_rate_df.head())
# Out:
# GDP DataFrame:
#          Country Country Code  Year  GDP (current US$)
# 0  United States          USA  2023                NaN
# 1  United States          USA  2022       2.543970e+13
# 2  United States          USA  2021       2.331508e+13
# 3  United States          USA  2020       2.106047e+13
# 4  United States          USA  2019       2.138098e+13
#
# Inflation Rate DataFrame:
#   realtime_start realtime_end        date  value
# 0     2024-05-23   2024-05-23  1947-01-01  21.48
# 1     2024-05-23   2024-05-23  1947-02-01  21.62
# 2     2024-05-23   2024-05-23  1947-03-01   22.0
# 3     2024-05-23   2024-05-23  1947-04-01   22.0
# 4     2024-05-23   2024-05-23  1947-05-01  21.95
#
# Unemployment Rate DataFrame:
#   realtime_start realtime_end        date value
# 0     2024-06-07   2024-06-07  1948-01-01   3.4
# 1     2024-06-07   2024-06-07  1948-02-01   3.8
# 2     2024-06-07   2024-06-07  1948-03-01   4.0
# 3     2024-06-07   2024-06-07  1948-04-01   3.9
# ...

# %%
print("Interest Rates Data:", interest_rates_data)
print("Consumer Confidence Index Data:", consumer_confidence_index_data)
print("Retail Sales Data:", retail_sales_data)
print("Industrial Production Data:", industrial_production_data)
print("Housing Starts Data:", housing_starts_data)
print("Trade Balance Data:", trade_balance_data)
print("Government Debt Data:", government_debt_data)
# Out:
# Unemployment Rate Data: {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'observation_start': '1600-01-01', 'observation_end': '9999-12-31', 'units': 'lin', 'output_type': 1, 'file_type': 'json', 'order_by': 'observation_date', 'sort_order': 'asc', 'count': 916, 'offset': 0, 'limit': 100000, 'observations': [{'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-01-01', 'value': '3.4'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-02-01', 'value': '3.8'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-03-01', 'value': '4.0'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-04-01', 'value': '3.9'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-05-01', 'value': '3.5'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23', 'date': '1948-06-01', 'value': '3.6'}, {'realtime_start': '2024-05-23', 'realtime_end': '2024-05-23',
# ...
